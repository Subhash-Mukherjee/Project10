# %% [markdown]
# **Temp of Abidjan**

# %%
import io
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dd693c28-f932-4dea-9d55-f91d7a96c59c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd693c28-f932-4dea-9d55-f91d7a96c59c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving temp.csv to temp.csv

# %%
df=pd.read_csv(io.BytesIO(uploaded['temp.csv']))

# %%
df.head()
# Out:
#    Unnamed: 0  avg_temp_c     city        country        date
# 0           0      27.293  Abidjan  Côte D'Ivoire  2000-01-01
# 1           1      27.685  Abidjan  Côte D'Ivoire  2000-02-01
# 2           2      29.061  Abidjan  Côte D'Ivoire  2000-03-01
# 3           3      28.162  Abidjan  Côte D'Ivoire  2000-04-01
# 4           4      27.547  Abidjan  Côte D'Ivoire  2000-05-01

# %%
sns.relplot(x='date' ,y='avg_temp_c', data=df, kind ='line')
plt.show()
